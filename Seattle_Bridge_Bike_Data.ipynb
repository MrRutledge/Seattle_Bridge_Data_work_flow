# %% [markdown]
# # ***Seattle Bridge data work flow***
# ### Commuting cyclists crossing the bridge

# %% [markdown]
# ### Importing  the libraries
#
# #### Analysis libraries

# %%
import numpy as np
import pandas as pd 
from jupyterthemes import jtplot

# %% [markdown]
# ##### Visualization Libraries

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,7)
plt.style.use(['seaborn','dark_background'])

# %% [markdown]
# ##### Scikit Learn imports

# %%
from sklearn.decomposition import PCA
from sklearn.mixture import GaussianMixture

# %% [markdown]
# ### Importing the data

# %%
from jupyterworkflow.data import get_fremont_data
data = get_fremont_data()

# %% [markdown]
# ### Data inspection

# %%
data.head()
# Out:
#                      West  East  Total
# Date
# 2012-10-03 00:00:00   9.0   4.0   13.0
# 2012-10-03 01:00:00   6.0   4.0   10.0
# 2012-10-03 02:00:00   1.0   1.0    2.0
# 2012-10-03 03:00:00   3.0   2.0    5.0
# 2012-10-03 04:00:00   1.0   6.0    7.0

# %%
data.describe()
# Out:
#                West          East         Total
# count  51063.000000  51063.000000  51063.000000
# mean      57.126902     53.654329    110.781231
# std       82.685731     70.067851    139.511157
# min        0.000000      0.000000      0.000000
# 25%        7.000000      7.000000     15.000000
# 50%       29.000000     29.000000     60.000000
# 75%       70.000000     71.000000    145.000000
# max      717.000000    698.000000    957.000000

# %%
data.count()
# Out:
# West     51063
# East     51063
# Total    51063
# dtype: int64

# %% [markdown]
#   ## Using Pandas resample to get the overall picture of the whole data.

# %% [markdown]
# #### Notice how just by using the resample we can gain some insight on the data and how the usage of this bridge changes over time.  *Hourly*, *Daily*, *Weekly*, *Monthly* and *Annually*.

# %%
data.resample('D').sum().plot(grid=False)
plt.ylabel('Daily trips')
plt.title('Daily Trips VS Date')
# Out:
# Text(0.5, 1.0, 'Daily Trips VS Date')

# %%
data.resample('W').sum().plot(grid=False)
plt.ylabel('Weekly trips')
plt.title('Weekly Trips VS Date')
# Out:
# Text(0.5, 1.0, 'Weekly Trips VS Date')

# %%
data.resample('M').sum().plot(grid=False)
plt.ylabel('Monthly trips')
plt.title('Monthly Trips VS Date')
# Out:
# Text(0.5, 1.0, 'Monthly Trips VS Date')

# %%
data.resample('Y').sum().plot(grid=False)
plt.ylabel('Annual trips')
plt.title('Annual Trips VS Date')
# Out:
# Text(0.5, 1.0, 'Annual Trips VS Date')

# %%
plt.subplots()
plt.title('Weekly Trips VS Date\n east & waste')
plt.ylabel('Weekly trips')
data['East'].resample('W').sum().plot(legend=True)
data['West'].resample('W').sum().plot(legend = True, grid=False)

# %%
plt.subplots()
plt.ylabel('Hourly trips')
plt.title('Hourly Trips VS Date')
data['East'].resample('H').sum().plot(legend=True)
data['West'].resample('H').sum().plot(legend = True, grid= False)

# %%
data['Total'] = data['West'] + data['East']
ax = data.resample('D').sum().rolling(365).sum().plot(grid=False);
ax.set_ylim(0,None);

# %%
data.groupby(data.index.time).mean().plot(grid=False)
plt.ylabel('Number of trips at a given time')
plt.title('Number of trips VS Time of the day')
# Out:
# Text(0.5, 1.0, 'Number of trips VS Time of the day')

# %%
data.head()
# Out:
#                      West  East  Total
# Date
# 2012-10-03 00:00:00   9.0   4.0   13.0
# 2012-10-03 01:00:00   6.0   4.0   10.0
# 2012-10-03 02:00:00   1.0   1.0    2.0
# 2012-10-03 03:00:00   3.0   2.0    5.0
# 2012-10-03 04:00:00   1.0   6.0    7.0

# %%
pivoted = data.pivot_table('Total',index=data.index.time, columns=data.index.date)
pivoted.iloc[:10,:5]
# Out:
#           2012-10-03  2012-10-04  2012-10-05  2012-10-06  2012-10-07
# 00:00:00        13.0        18.0        11.0        15.0        11.0
# 01:00:00        10.0         3.0         8.0        15.0        17.0
# 02:00:00         2.0         9.0         7.0         9.0         3.0
# 03:00:00         5.0         3.0         4.0         3.0         6.0
# 04:00:00         7.0         8.0         9.0         5.0         3.0
# 05:00:00        31.0        26.0        25.0         5.0         9.0
# 06:00:00       155.0       142.0       105.0        27.0        17.0
# 07:00:00       352.0       319.0       319.0        33.0        26.0
# 08:00:00       437.0       418.0       370.0       105.0        69.0
# 09:00:00       276.0       241.0       212.0       114.0       103.0

# %%
pivoted.plot(grid= False ,legend = False)

# %%
pivoted.index[:24]
# Out:
# Index([00:00:00, 01:00:00, 02:00:00, 03:00:00, 04:00:00, 05:00:00, 06:00:00,
#        07:00:00, 08:00:00, 09:00:00, 10:00:00, 11:00:00, 12:00:00, 13:00:00,
#        14:00:00, 15:00:00, 16:00:00, 17:00:00, 18:00:00, 19:00:00, 20:00:00,
#        21:00:00, 22:00:00, 23:00:00],
#       dtype='object')

# %%
data.index
# Out:
# DatetimeIndex(['2012-10-03 00:00:00', '2012-10-03 01:00:00',
#                '2012-10-03 02:00:00', '2012-10-03 03:00:00',
#                '2012-10-03 04:00:00', '2012-10-03 05:00:00',
#                '2012-10-03 06:00:00', '2012-10-03 07:00:00',
#                '2012-10-03 08:00:00', '2012-10-03 09:00:00',
#                ...
#                '2018-07-31 14:00:00', '2018-07-31 15:00:00',
#                '2018-07-31 16:00:00', '2018-07-31 17:00:00',
#                '2018-07-31 18:00:00', '2018-07-31 19:00:00',
#                '2018-07-31 20:00:00', '2018-07-31 21:00:00',
#                '2018-07-31 22:00:00', '2018-07-31 23:00:00'],
#               dtype='datetime64[ns]', name='Date', length=51072, freq=None)

# %% [markdown]
# ## Scikit Learn to do further analysis of the data.

# %%
x  =pivoted.fillna(0).T.values
x.shape
# Out:
# (2128, 24)

# %%
#treating each day as a projection using principle component analysis
x2 = PCA(2, svd_solver='full').fit_transform(x)

# %%
plt.scatter(x2[:,0],x2[:,1])
plt.grid(False)

# %% [markdown]
# ### using the gaussian mixture model to identify where the days fall

# %%
gmm = GaussianMixture(2)
gmm.fit(x)
labels = gmm.predict(x)
labels
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %%
plt.scatter(x2[:,0],x2[:,1], c=labels, cmap='rainbow', grid= False)
plt.grid -False
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-29712a4c2c22> in <module>
# ----> 1 plt.scatter(x2[:,0],x2[:,1], c=labels, cmap='rainbow', grid= False)
#
# ~/.local/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2860         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2861         verts=verts, edgecolors=edgecolors, **({"data": data} if data
# -> 2862         is not None else {}), **kwargs)
#    2863     sci(__ret)
#    2864     return __ret
#
# ~/.local/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/.local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4298                 )
#    4299         collection.set_transform(mtransforms.IdentityTransform())
# -> 4300         collection.update(kwargs)
#    4301
#    4302         if colors is None:
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in update(self, props)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
# --> 916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#     918         if len(ret):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in <listcomp>(.0)
#     914
#     915         with cbook._setattr_cm(self, eventson=False):
# --> 916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#     918         if len(ret):
#
# ~/.local/lib/python3.7/site-packages/matplotlib/artist.py in _update_property(self, k, v)
#     910                 func = getattr(self, 'set_' + k, None)
#     911                 if not callable(func):
# --> 912                     raise AttributeError('Unknown property %s' % k)
#     913                 return func(v)
#     914
#
# AttributeError: Unknown property grid

# %% [markdown]
# ##  Commuting days vs Non commuting days

# %%
pivoted.T[labels == 0].T.plot(legend = False, alpha = 0.20, grid= False)
pivoted.T[labels == 1].T.plot(legend = False, alpha = 0.20, grid= False)

# %%
daysofweek = pd.DatetimeIndex(pivoted.columns).dayofweek

# %%
plt.scatter(x2[:,0],x2[:,1], c=daysofweek, cmap='rainbow', grid= False)
cb = plt.colorbar(ticks=range(7))
cb.set_ticklabels(['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun'])

# %% [markdown]
# ## Zooming in on the days of the week that happen to land on the non commuter days to see whats happening

# %%
dates = pd.DatetimeIndex(pivoted.columns)
dates[(labels == 0)& (daysofweek < 5)]
